# %% [markdown]
# # Data Engineering Project Instructions
#
# ## Preparation
# * You will need to install `boto3`
# * You will be using `pandas` and `configparser`
# * You will need to install two additional libraries to support pandas in reading from S3:
# ```bash
#   conda install s3fs -c conda-forge -y
#   conda install fsspec -y
# ```
#
# ## Transformations
#
# You will perform the same transformations you did in the previous class, including:
#
# * __Calculate Trip Duration in Minutes:__ Call it Trip_Duration.
# * __Calculate Total Trip Charge:__ Include fare amount, extra, MTA tax, tolls amount, improvement surcharge, congestion surcharge, airport fee, and tip amount. Call it Total_Trip_Charge.
# * __Add Trip Date Components:__ Add `Trip_Date`, `Trip_Month`, `Trip_Day`, and `Trip_Year`.
# * __Keep Specific Columns:__ `VendorID`, `passenger_count`, `trip_distance`, `store_and_fwd_flag`, `payment_type`, `Trip_Duration`, `Total_Trip_Charge`, `Trip_Date`, `Trip_Month`, `Trip_Year`, `Trip_Day`
# * __Reorder the Columns:__ Start with VendorID, followed by all the date/time columns (Date, Year, Month, and Day), then the remaining columns.
# * __Rename the Columns:__ Rename columns to Vendor_ID, No_of_Passengers, SF_Flag, Payment_Type.
#
# ## Expectation Part 1
#
# * You will create functions to support your ETL Process.
# * You will need to capture some statistics for each data set you are processing for reference.
# * You will read from a source S3 bucket (raw) and write into a different S3 bucket (transformed):
# ```python
# bucket_dest = 'techcatalyst-transformed'
# bucket_source = 'techcatalyst-raw'
# ```
# * Make sure that your files "objects" are under your name inside the `techcatalyst-transformed` bucket. For example:
# s3://techcatalyst-transformed/tarek/yellow_tripdata_2024-01_transformed.parquet/Trip_Year=2024/Trip_Month=January/84e2f047dcff4f7183ae25518ecd486b-0.parquet
# * Create a function that generates an `s3://` URI. The function should take a bucket name, a file name, and then construct an `s3://` URI that points to the object. Refer to this link for more details on S3 URIs. If you forget how the `s3://` URI looks, please log in to AWS and navigate to S3 services to see how an object inside a bucket is being referenced by the `s3://` URI.
# * Create a **cleanup** function that takes three *parameters*: the DataFrame, the name of the file, and the destination bucket. The function will transform the data, then write out a Parquet file to the destination address.
# * You may need to create additional functions as necessary.
# * Finally, once you write the files to S3, you will also write your statistic file. For example., capture number of rows, number of columns, number of columns with null values, date/time of processing. What else can you think of?
# * While processing each file, it would be great to log something on the screen to show progress or status. Here is an example below:
#
# ```
# processing yellow_tripdata_2024-01.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-01.parquet to techcatalyst-transformed bucket
# ...........
# processing yellow_tripdata_2024-02.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-02.parquet to techcatalyst-transformed bucket
# ...........
# processing yellow_tripdata_2024-03.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-03.parquet to techcatalyst-transformed bucket
# ...........
# processing yellow_tripdata_2024-04.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-04.parquet to techcatalyst-transformed bucket
# ...........
# ```
#
#
#
# # Expectation Part 2
# * Once the data has been loaded on AWS, you will need to use Athena to inspect the data to ensure correctness.
# * Remember, before using Athena, you will need to go through the process of creating the crawlers and other setup steps.

# %%
# !conda install -c conda-forge boto3 -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/npatturi/miniconda3/envs/dev1
#
#   added / updated specs:
#     - boto3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boto3-1.34.134             |     pyhd8ed1ab_0          79 KB  conda-forge
#     botocore-1.34.134          |pyge310_1234567_0         6.7 MB  conda-forge
#     brotli-python-1.1.0        |  py311hb755f60_1         343 KB  conda-forge
#     cffi-1.16.0                |  py311hb3a22ac_0         293 KB  conda-forge
#     h2-4.1.0                   |     pyhd8ed1ab_0          46 KB  conda-forge
#     hpack-4.0.0                |     pyh9f0ad1d_0          25 KB  conda-forge
#     hyperframe-6.0.1           |     pyhd8ed1ab_0          14 KB  conda-forge
#     jmespath-1.0.1             |     pyhd8ed1ab_0          21 KB  conda-forge
#     pycparser-2.22             |     pyhd8ed1ab_0         103 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     s3transfer-0.10.2          |     pyhd8ed1ab_0          61 KB  conda-forge
#     urllib3-2.2.2              |     pyhd8ed1ab_1          93 KB  conda-forge
#     zstandard-0.22.0           |  py311hb6f056b_1         405 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         8.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   boto3              conda-forge/noarch::boto3-1.34.134-pyhd8ed1ab_0
#   botocore           conda-forge/noarch::botocore-1.34.134-pyge310_1234567_0
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py311hb755f60_1
#   cffi               conda-forge/linux-64::cffi-1.16.0-py311hb3a22ac_0
#   h2                 conda-forge/noarch::h2-4.1.0-pyhd8ed1ab_0
#   hpack              conda-forge/noarch::hpack-4.0.0-pyh9f0ad1d_0
#   hyperframe         conda-forge/noarch::hyperframe-6.0.1-pyhd8ed1ab_0
#   jmespath           conda-forge/noarch::jmespath-1.0.1-pyhd8ed1ab_0
#   pycparser          conda-forge/noarch::pycparser-2.22-pyhd8ed1ab_0
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   s3transfer         conda-forge/noarch::s3transfer-0.10.2-pyhd8ed1ab_0
#   urllib3            conda-forge/noarch::urllib3-2.2.2-pyhd8ed1ab_1
#   zstandard          conda-forge/linux-64::zstandard-0.22.0-py311hb6f056b_1
#
#
#
# Downloading and Extracting Packages:
# botocore-1.34.134    | 6.7 MB    |                                       |   0%
# zstandard-0.22.0     | 405 KB    |                                       |   0%
#
# brotli-python-1.1.0  | 343 KB    |                                       |   0%
#
#
# cffi-1.16.0          | 293 KB    |                                       |   0%
#
#
#
# pycparser-2.22       | 103 KB    |                                       |   0%
#
#
#
#
# urllib3-2.2.2        | 93 KB     |                                       |   0%
#
#
#
#
#
# boto3-1.34.134       | 79 KB     |                                       |   0%
#
#
#
#
#
#
# s3transfer-0.10.2    | 61 KB     |                                       |   0%
#
#
#
#
#
#
#
# h2-4.1.0             | 46 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# hpack-4.0.0          | 25 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# jmespath-1.0.1       | 21 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 19 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# botocore-1.34.134    | 6.7 MB    |                                       |   0%
# zstandard-0.22.0     | 405 KB    | #4                                    |   4%
#
# brotli-python-1.1.0  | 343 KB    | #7                                    |   5%
#
#
#
# pycparser-2.22       | 103 KB    | #####7                                |  16%
#
#
# botocore-1.34.134    | 6.7 MB    | #############5                        |  37%
#
#
#
#
# urllib3-2.2.2        | 93 KB     | ######3                               |  17%
#
#
#
#
#
# boto3-1.34.134       | 79 KB     | #######4                              |  20%
#
#
#
#
#
#
# s3transfer-0.10.2    | 61 KB     | #########6                            |  26%
#
#
#
#
#
#
#
# h2-4.1.0             | 46 KB     | ############9                         |  35%
#
#
#
#
#
#
#
#
# hpack-4.0.0          | 25 KB     | #######################9              |  65%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 19 KB     | ###############################9      |  86%
# zstandard-0.22.0     | 405 KB    | ##################################### | 100%
# zstandard-0.22.0     | 405 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# jmespath-1.0.1       | 21 KB     | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
# hyperframe-6.0.1     | 14 KB     | ##################################### | 100%
#
# brotli-python-1.1.0  | 343 KB    | ##################################### | 100%
#
# brotli-python-1.1.0  | 343 KB    | ##################################### | 100%
#
#
# cffi-1.16.0          | 293 KB    | ##################################### | 100%
#
#
# cffi-1.16.0          | 293 KB    | ##################################### | 100%
#
#
#
# pycparser-2.22       | 103 KB    | ##################################### | 100%
#
#
#
#
# urllib3-2.2.2        | 93 KB     | ##################################### | 100%
#
#
#
#
# urllib3-2.2.2        | 93 KB     | ##################################### | 100%
#
#
#
# pycparser-2.22       | 103 KB    | ##################################### | 100%
#
#
#
#
#
#
# s3transfer-0.10.2    | 61 KB     | ##################################### | 100%
#
#
#
#
#
#
# s3transfer-0.10.2    | 61 KB     | ##################################### | 100%
#
#
#
#
#
# boto3-1.34.134       | 79 KB     | ##################################### | 100%
#
#
#
#
#
# boto3-1.34.134       | 79 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# h2-4.1.0             | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# h2-4.1.0             | 46 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# hpack-4.0.0          | 25 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# hpack-4.0.0          | 25 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 19 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# jmespath-1.0.1       | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# jmespath-1.0.1       | 21 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
import boto3

# %%
import configparser

# %%
config = configparser.ConfigParser()

# %%
config.read('aws.cfg')
# Out:
# ['aws.cfg']

# %%
AWS_ACCESS_KEY = config['AWS']['aws_access_key']
AWS_SECRET_KEY = config['AWS']['aws_secret_key']

# %%
AWS_SECRET_KEY
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 AWS_SECRET_KEY
#
# NameError: name 'AWS_SECRET_KEY' is not defined

# %%
# establish your S3 client 
# https://boto3.amazonaws.com/v1/documentation/api/latest/guide/s3-example-creating-buckets.html
# make sure to pass your credentials: aws_access_key_id and aws_secret_access_key
s3client = boto3.client('s3', aws_access_key_id = AWS_ACCESS_KEY, aws_secret_access_key = AWS_SECRET_KEY)

# %%
# submit the query to get back all the buckets in the account and store in the response variable 
response = s3client.list_buckets()

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '02H0N1RB7SB0TJ3Q',
#   'HostId': 'EJnvvsea0XxIwl97JHge12O5e9BOg6K9CsGJPgrFw1ytvWnl1tH+9KVCATlHB8FD6zBWFIJ7frk=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'EJnvvsea0XxIwl97JHge12O5e9BOg6K9CsGJPgrFw1ytvWnl1tH+9KVCATlHB8FD6zBWFIJ7frk=',
#    'x-amz-request-id': '02H0N1RB7SB0TJ3Q',
#    'date': 'Thu, 27 Jun 2024 17:30:02 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Buckets': [{'Name': 'amsu-aws-s3-assessment',
#    'CreationDate': datetime.datetime(2023, 9, 8, 16, 49, 14, tzinfo=tzutc())},
#   {'Name': 'amsu-s3-cf-website',
#    'CreationDate': datetime.datetime(2023, 9, 7, 13, 50, 19, tzinfo=tzutc())},
#   {'Name': 'andrea-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 6, 17, 40, 27, tzinfo=tzutc())},
#   {'Name': 'aryan-aws-glue-activity-raw',
#    'CreationDate': datetime.datetime(2024, 6, 20, 17, 59, 50, tzinfo=tzutc())},
#   {'Name': 'aryan-aws-glue-activity-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 7, 10, tzinfo=tzutc())},
#   {'Name': 'austin-lambda-s3',
#    'CreationDate': datetime.datetime(2023, 9, 19, 16, 14, 35, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-1-535146832369',
#    'CreationDate': datetime.datetime(2024, 6, 20, 20, 30, 55, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-1-535146832369-andy',
#    'CreationDate': datetime.datetime(2024, 6, 20, 20, 56, 38, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-1-535146832369nh',
#    'CreationDate': datetime.datetime(2024, 6, 20, 20, 45, 4, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-1-aryan',
#    'CreationDate': datetime.datetime(2024, 6, 20, 19, 28, 36, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-1-tarek',
#    'CreationDate': datetime.datetime(2024, 6, 19, 15, 17, 21, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-2-535146832369',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 56, 27, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-2-535146832369-kb',
#    'CreationDate': datetime.datetime(2024, 6, 20, 20, 10, 49, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-2-nsp',
#    'CreationDate': datetime.datetime(2024, 6, 21, 13, 34, 21, tzinfo=tzutc())},
#   {'Name': 'aws-athena-query-results-us-east-2-sp',
#    'CreationDate': datetime.datetime(2024, 6, 20, 20, 6, 50, tzinfo=tzutc())},
#   {'Name': 'aws-cloudtrail-logs-535146832369-01f575cd',
#    'CreationDate': datetime.datetime(2020, 12, 15, 20, 59, 58, tzinfo=tzutc())},
#   {'Name': 'aws-cloudtrail-logs-535146832369-9d19bcae',
#    'CreationDate': datetime.datetime(2020, 12, 15, 20, 53, 55, tzinfo=tzutc())},
#   {'Name': 'aws-glue-assets-535146832369-us-east-1',
#    'CreationDate': datetime.datetime(2024, 6, 19, 15, 41, 10, tzinfo=tzutc())},
#   {'Name': 'aws-glue-assets-535146832369-us-east-2',
#    'CreationDate': datetime.datetime(2024, 6, 20, 19, 24, 6, tzinfo=tzutc())},
#   {'Name': 'aws-sam-cli-managed-default-samclisourcebucket-1oz2tqbsdli3',
#    'CreationDate': datetime.datetime(2023, 9, 21, 15, 58, 27, tzinfo=tzutc())},
#   {'Name': 'aws-sam-cli-managed-default-samclisourcebucket-mgdplk7mifi7',
#    'CreationDate': datetime.datetime(2023, 9, 20, 11, 2, 16, tzinfo=tzutc())},
#   {'Name': 'aws-sam-cli-managed-default-samclisourcebucket-t2x2wb9il3p1',
#    'CreationDate': datetime.datetime(2023, 9, 20, 16, 22, 33, tzinfo=tzutc())},
#   {'Name': 'aws-sam-cli-managed-default-samclisourcebucket-yh6y67cvomwp',
#    'CreationDate': datetime.datetime(2023, 9, 20, 16, 29, 1, tzinfo=tzutc())},
#   {'Name': 'axel-di-student14',
#    'CreationDate': datetime.datetime(2024, 3, 20, 15, 54, 12, tzinfo=tzutc())},
#   {'Name': 'axel-di-student2',
#    'CreationDate': datetime.datetime(2024, 3, 20, 16, 44, 18, tzinfo=tzutc())},
#   {'Name': 'axel-di-student25',
#    'CreationDate': datetime.datetime(2024, 3, 20, 20, 4, 31, tzinfo=tzutc())},
#   {'Name': 'axel-di-student8',
#    'CreationDate': datetime.datetime(2024, 3, 20, 16, 26, 54, tzinfo=tzutc())},
#   {'Name': 'axel-di-team2',
#    'CreationDate': datetime.datetime(2024, 3, 20, 16, 40, 32, tzinfo=tzutc())},
#   {'Name': 'barb-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 7, 17, 55, tzinfo=tzutc())},
#   {'Name': 'brian-s3-demo',
#    'CreationDate': datetime.datetime(2019, 9, 23, 15, 50, 51, tzinfo=tzutc())},
#   {'Name': 'bryantbeach-original-images',
#    'CreationDate': datetime.datetime(2022, 6, 28, 18, 14, 48, tzinfo=tzutc())},
#   {'Name': 'bryantbeach-thumbnail-images',
#    'CreationDate': datetime.datetime(2022, 6, 28, 18, 15, 6, tzinfo=tzutc())},
#   {'Name': 'bucket-cl05355',
#    'CreationDate': datetime.datetime(2024, 6, 26, 14, 50, 18, tzinfo=tzutc())},
#   {'Name': 'bucket-terraform-lab4-41091',
#    'CreationDate': datetime.datetime(2023, 10, 19, 19, 23, 32, tzinfo=tzutc())},
#   {'Name': 'bucket-terraform-lab4-67147',
#    'CreationDate': datetime.datetime(2024, 3, 19, 19, 35, 1, tzinfo=tzutc())},
#   {'Name': 'bucket-terraform-lab4-82140',
#    'CreationDate': datetime.datetime(2023, 10, 19, 19, 23, 52, tzinfo=tzutc())},
#   {'Name': 'bucket-terraform-lab4-95407',
#    'CreationDate': datetime.datetime(2023, 10, 19, 19, 31, 55, tzinfo=tzutc())},
#   {'Name': 'bucket-terraform-lab4-98294',
#    'CreationDate': datetime.datetime(2023, 10, 19, 19, 53, 23, tzinfo=tzutc())},
#   {'Name': 'buggy-535146832369-us-east-1',
#    'CreationDate': datetime.datetime(2023, 9, 21, 18, 11, 34, tzinfo=tzutc())},
#   {'Name': 'bugs-app-stack-535146832369-us-east-2',
#    'CreationDate': datetime.datetime(2023, 9, 21, 17, 38, 24, tzinfo=tzutc())},
#   {'Name': 'calvin-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 4, 14, 28, 41, tzinfo=tzutc())},
#   {'Name': 'capstone-cloud-template-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 15, 16, 54, 6, tzinfo=tzutc())},
#   {'Name': 'capstone-service-image',
#    'CreationDate': datetime.datetime(2023, 9, 22, 20, 54, 8, tzinfo=tzutc())},
#   {'Name': 'cf-templates-6dazn7owsddb-ap-south-1',
#    'CreationDate': datetime.datetime(2023, 9, 7, 20, 40, 52, tzinfo=tzutc())},
#   {'Name': 'cf-templates-6dazn7owsddb-us-east-1',
#    'CreationDate': datetime.datetime(2019, 10, 28, 17, 21, 12, tzinfo=tzutc())},
#   {'Name': 'cf-templates-6dazn7owsddb-us-east-2',
#    'CreationDate': datetime.datetime(2019, 9, 25, 23, 36, 51, tzinfo=tzutc())},
#   {'Name': 'cf-templates-6dazn7owsddb-us-west-2',
#    'CreationDate': datetime.datetime(2019, 10, 28, 14, 52, 14, tzinfo=tzutc())},
#   {'Name': 'codepipeline-us-east-2-68716816310',
#    'CreationDate': datetime.datetime(2024, 6, 26, 21, 58, 28, tzinfo=tzutc())},
#   {'Name': 'connor-awsassignment',
#    'CreationDate': datetime.datetime(2023, 9, 8, 18, 20, 29, tzinfo=tzutc())},
#   {'Name': 'connor-lambda-s3',
#    'CreationDate': datetime.datetime(2023, 9, 19, 16, 14, 44, tzinfo=tzutc())},
#   {'Name': 'connor-s3-cf-final-website',
#    'CreationDate': datetime.datetime(2023, 9, 7, 13, 50, 18, tzinfo=tzutc())},
#   {'Name': 'connor-s3-sqs',
#    'CreationDate': datetime.datetime(2023, 9, 18, 19, 55, 28, tzinfo=tzutc())},
#   {'Name': 'connorsbucketdemo',
#    'CreationDate': datetime.datetime(2023, 9, 6, 15, 17, 30, tzinfo=tzutc())},
#   {'Name': 'countingbucket-0',
#    'CreationDate': datetime.datetime(2022, 3, 29, 8, 23, 27, tzinfo=tzutc())},
#   {'Name': 'countingbucket-1',
#    'CreationDate': datetime.datetime(2022, 3, 29, 8, 23, 27, tzinfo=tzutc())},
#   {'Name': 'countingbucket-2',
#    'CreationDate': datetime.datetime(2022, 3, 29, 8, 23, 27, tzinfo=tzutc())},
#   {'Name': 'craig-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 4, 17, 0, 12, tzinfo=tzutc())},
#   {'Name': 'darrell-assessment-s3',
#    'CreationDate': datetime.datetime(2023, 9, 8, 14, 18, 4, tzinfo=tzutc())},
#   {'Name': 'david-s3-angular-assesment',
#    'CreationDate': datetime.datetime(2023, 9, 8, 13, 30, 18, tzinfo=tzutc())},
#   {'Name': 'davidprivatebucket',
#    'CreationDate': datetime.datetime(2023, 9, 7, 13, 55, 6, tzinfo=tzutc())},
#   {'Name': 'ddd434278923423',
#    'CreationDate': datetime.datetime(2022, 1, 6, 15, 54, 30, tzinfo=tzutc())},
#   {'Name': 'devint-2373',
#    'CreationDate': datetime.datetime(2024, 3, 19, 19, 14, 26, tzinfo=tzutc())},
#   {'Name': 'devint-4633',
#    'CreationDate': datetime.datetime(2024, 3, 19, 18, 46, 13, tzinfo=tzutc())},
#   {'Name': 'devint-6326',
#    'CreationDate': datetime.datetime(2024, 3, 13, 15, 49, 5, tzinfo=tzutc())},
#   {'Name': 'devint-8987',
#    'CreationDate': datetime.datetime(2024, 3, 13, 15, 43, 10, tzinfo=tzutc())},
#   {'Name': 'devint-auser1',
#    'CreationDate': datetime.datetime(2022, 2, 28, 15, 12, 46, tzinfo=tzutc())},
#   {'Name': 'devint-auser2',
#    'CreationDate': datetime.datetime(2022, 2, 28, 15, 12, 46, tzinfo=tzutc())},
#   {'Name': 'devint-dan2238',
#    'CreationDate': datetime.datetime(2023, 10, 18, 21, 14, 14, tzinfo=tzutc())},
#   {'Name': 'devint-krueger-alt',
#    'CreationDate': datetime.datetime(2022, 1, 7, 9, 30, 17, tzinfo=tzutc())},
#   {'Name': 'devint-std14-20220329062534398200000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 25, 35, tzinfo=tzutc())},
#   {'Name': 'devint-std14-20220329062534458500000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 25, 35, tzinfo=tzutc())},
#   {'Name': 'devint-std14-alt',
#    'CreationDate': datetime.datetime(2022, 3, 28, 13, 14, 9, tzinfo=tzutc())},
#   {'Name': 'devint-std17-20220329063555600900000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 35, 57, tzinfo=tzutc())},
#   {'Name': 'devint-std17-20220329063555696700000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 35, 56, tzinfo=tzutc())},
#   {'Name': 'devint-std17-alt',
#    'CreationDate': datetime.datetime(2022, 3, 28, 13, 12, 22, tzinfo=tzutc())},
#   {'Name': 'devint-std18-20220329063643571000000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 36, 44, tzinfo=tzutc())},
#   {'Name': 'devint-std18-20220329063644010600000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 36, 46, tzinfo=tzutc())},
#   {'Name': 'devint-std30-20220329110905171700000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 11, 9, 6, tzinfo=tzutc())},
#   {'Name': 'devint-std4-alt',
#    'CreationDate': datetime.datetime(2022, 3, 28, 12, 46, 20, tzinfo=tzutc())},
#   {'Name': 'devint-std7-alt',
#    'CreationDate': datetime.datetime(2022, 3, 28, 13, 40, 9, tzinfo=tzutc())},
#   {'Name': 'devint-std8-20220329064413559800000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 44, 14, tzinfo=tzutc())},
#   {'Name': 'devint-std8-20220329064414038300000001',
#    'CreationDate': datetime.datetime(2022, 3, 29, 6, 44, 15, tzinfo=tzutc())},
#   {'Name': 'devint-student1-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student1-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 11, tzinfo=tzutc())},
#   {'Name': 'devint-student10-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student10-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 11, tzinfo=tzutc())},
#   {'Name': 'devint-student11-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 48, tzinfo=tzutc())},
#   {'Name': 'devint-student11-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 20, tzinfo=tzutc())},
#   {'Name': 'devint-student12-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student12-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 19, tzinfo=tzutc())},
#   {'Name': 'devint-student13-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student13-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 27, tzinfo=tzutc())},
#   {'Name': 'devint-student14',
#    'CreationDate': datetime.datetime(2023, 10, 18, 17, 17, 41, tzinfo=tzutc())},
#   {'Name': 'devint-student14-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student14-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 13, tzinfo=tzutc())},
#   {'Name': 'devint-student15-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student15-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 17, tzinfo=tzutc())},
#   {'Name': 'devint-student16-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student16-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 21, tzinfo=tzutc())},
#   {'Name': 'devint-student17-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 48, tzinfo=tzutc())},
#   {'Name': 'devint-student17-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 12, tzinfo=tzutc())},
#   {'Name': 'devint-student18-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student18-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 12, tzinfo=tzutc())},
#   {'Name': 'devint-student19-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student19-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 20, tzinfo=tzutc())},
#   {'Name': 'devint-student2-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student2-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 25, tzinfo=tzutc())},
#   {'Name': 'devint-student20',
#    'CreationDate': datetime.datetime(2023, 10, 18, 18, 46, 37, tzinfo=tzutc())},
#   {'Name': 'devint-student20-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student20-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 12, tzinfo=tzutc())},
#   {'Name': 'devint-student21-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student21-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 25, tzinfo=tzutc())},
#   {'Name': 'devint-student22',
#    'CreationDate': datetime.datetime(2023, 10, 18, 19, 1, 44, tzinfo=tzutc())},
#   {'Name': 'devint-student22-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 48, tzinfo=tzutc())},
#   {'Name': 'devint-student22-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 12, tzinfo=tzutc())},
#   {'Name': 'devint-student23-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student23-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 13, tzinfo=tzutc())},
#   {'Name': 'devint-student24-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 49, tzinfo=tzutc())},
#   {'Name': 'devint-student24-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 22, tzinfo=tzutc())},
#   {'Name': 'devint-student25-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student3-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 46, tzinfo=tzutc())},
#   {'Name': 'devint-student3-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 22, tzinfo=tzutc())},
#   {'Name': 'devint-student4-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 46, tzinfo=tzutc())},
#   {'Name': 'devint-student4-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 17, tzinfo=tzutc())},
#   {'Name': 'devint-student5-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 49, tzinfo=tzutc())},
#   {'Name': 'devint-student5-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 20, tzinfo=tzutc())},
#   {'Name': 'devint-student6-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student6-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 26, tzinfo=tzutc())},
#   {'Name': 'devint-student7-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 46, tzinfo=tzutc())},
#   {'Name': 'devint-student7-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 26, tzinfo=tzutc())},
#   {'Name': 'devint-student8-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 42, tzinfo=tzutc())},
#   {'Name': 'devint-student8-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 20, tzinfo=tzutc())},
#   {'Name': 'devint-student9',
#    'CreationDate': datetime.datetime(2023, 10, 18, 17, 3, 39, tzinfo=tzutc())},
#   {'Name': 'devint-student9-2515',
#    'CreationDate': datetime.datetime(2024, 4, 3, 23, 32, 45, tzinfo=tzutc())},
#   {'Name': 'devint-student9-4241',
#    'CreationDate': datetime.datetime(2024, 3, 18, 15, 6, 11, tzinfo=tzutc())},
#   {'Name': 'devint-tabrej-alam-alt',
#    'CreationDate': datetime.datetime(2022, 1, 6, 15, 35, 26, tzinfo=tzutc())},
#   {'Name': 'digitalnomads',
#    'CreationDate': datetime.datetime(2020, 12, 8, 20, 24, 58, tzinfo=tzutc())},
#   {'Name': 'dooku2',
#    'CreationDate': datetime.datetime(2022, 1, 6, 15, 46, 50, tzinfo=tzutc())},
#   {'Name': 'dspera-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 4, 16, 30, 19, tzinfo=tzutc())},
#   {'Name': 'dws-di-corleone',
#    'CreationDate': datetime.datetime(2022, 1, 6, 14, 23, 27, tzinfo=tzutc())},
#   {'Name': 'dws-di-dooku-20220107144313147600000001',
#    'CreationDate': datetime.datetime(2022, 1, 7, 14, 43, 15, tzinfo=tzutc())},
#   {'Name': 'dws-di-jocker',
#    'CreationDate': datetime.datetime(2022, 1, 6, 14, 56, 17, tzinfo=tzutc())},
#   {'Name': 'dws-di-krueger',
#    'CreationDate': datetime.datetime(2022, 1, 6, 14, 23, 32, tzinfo=tzutc())},
#   {'Name': 'dws-di-nosferatu',
#    'CreationDate': datetime.datetime(2022, 1, 6, 15, 8, 41, tzinfo=tzutc())},
#   {'Name': 'dws-di-nosferatu-alt',
#    'CreationDate': datetime.datetime(2022, 1, 6, 15, 24, 59, tzinfo=tzutc())},
#   {'Name': 'dws-di-ramkumar',
#    'CreationDate': datetime.datetime(2022, 1, 6, 14, 23, 54, tzinfo=tzutc())},
#   {'Name': 'dws-di-spike',
#    'CreationDate': datetime.datetime(2022, 1, 6, 14, 32, 15, tzinfo=tzutc())},
#   {'Name': 'dws-di-student10',
#    'CreationDate': datetime.datetime(2023, 10, 20, 14, 40, 28, tzinfo=tzutc())},
#   {'Name': 'dws-di-tabrej-alam',
#    'CreationDate': datetime.datetime(2022, 1, 6, 14, 21, 46, tzinfo=tzutc())},
#   {'Name': 'dws-kattegat-ragnar',
#    'CreationDate': datetime.datetime(2022, 1, 7, 11, 30, 40, tzinfo=tzutc())},
#   {'Name': 'eamonn-test-bucket-865',
#    'CreationDate': datetime.datetime(2020, 11, 11, 14, 6, 48, tzinfo=tzutc())},
#   {'Name': 'eksworkshop-535146832369-codepipeline-artifacts',
#    'CreationDate': datetime.datetime(2021, 6, 25, 16, 24, 18, tzinfo=tzutc())},
#   {'Name': 'elasticbeanstalk-us-east-1-535146832369',
#    'CreationDate': datetime.datetime(2019, 9, 23, 14, 2, 31, tzinfo=tzutc())},
#   {'Name': 'elasticbeanstalk-us-east-2-535146832369',
#    'CreationDate': datetime.datetime(2019, 9, 23, 14, 1, 7, tzinfo=tzutc())},
#   {'Name': 'eoanifoeanfeionfiobvnuem',
#    'CreationDate': datetime.datetime(2023, 9, 27, 17, 26, 25, tzinfo=tzutc())},
#   {'Name': 'ferfybucket-assessment',
#    'CreationDate': datetime.datetime(2023, 9, 8, 16, 49, 20, tzinfo=tzutc())},
#   {'Name': 'first-bucket-es05260',
#    'CreationDate': datetime.datetime(2024, 6, 26, 15, 9, 29, tzinfo=tzutc())},
#   {'Name': 'first-web-app-bucket',
#    'CreationDate': datetime.datetime(2024, 6, 1, 19, 25, 31, tzinfo=tzutc())},
#   {'Name': 'first-web-app-cs08090',
#    'CreationDate': datetime.datetime(2024, 6, 25, 19, 11, 28, tzinfo=tzutc())},
#   {'Name': 'georgethomas-original-images',
#    'CreationDate': datetime.datetime(2022, 6, 24, 18, 47, 22, tzinfo=tzutc())},
#   {'Name': 'georgethomas-thumbnail-images',
#    'CreationDate': datetime.datetime(2022, 6, 24, 18, 47, 39, tzinfo=tzutc())},
#   {'Name': 'hark-assessment-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 11, 14, 55, 46, tzinfo=tzutc())},
#   {'Name': 'hartford-bucket-andy-raw',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 19, 38, tzinfo=tzutc())},
#   {'Name': 'hartford-bucket-andy-raw-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 31, 55, tzinfo=tzutc())},
#   {'Name': 'hk-lambda-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 19, 16, 14, 51, tzinfo=tzutc())},
#   {'Name': 'jalaunsbucket',
#    'CreationDate': datetime.datetime(2024, 6, 26, 14, 28, 40, tzinfo=tzutc())},
#   {'Name': 'jamesbrett-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 5, 2, 21, 26, tzinfo=tzutc())},
#   {'Name': 'jc-aws-athena-query-results-us-east-1',
#    'CreationDate': datetime.datetime(2024, 6, 27, 15, 29, 52, tzinfo=tzutc())},
#   {'Name': 'joe-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 5, 22, 12, 1, tzinfo=tzutc())},
#   {'Name': 'jonathanbardwellsbucket',
#    'CreationDate': datetime.datetime(2019, 9, 23, 15, 50, 31, tzinfo=tzutc())},
#   {'Name': 'jrrickerson-demo-cohort7',
#    'CreationDate': datetime.datetime(2022, 6, 22, 18, 6, 32, tzinfo=tzutc())},
#   {'Name': 'juliev1-bucket',
#    'CreationDate': datetime.datetime(2019, 9, 23, 15, 50, 46, tzinfo=tzutc())},
#   {'Name': 'kerim-test-bucket',
#    'CreationDate': datetime.datetime(2020, 11, 12, 22, 48, 13, tzinfo=tzutc())},
#   {'Name': 'lab-two',
#    'CreationDate': datetime.datetime(2024, 6, 18, 19, 19, 5, tzinfo=tzutc())},
#   {'Name': 'lcates-original-images',
#    'CreationDate': datetime.datetime(2022, 6, 24, 18, 30, 39, tzinfo=tzutc())},
#   {'Name': 'lcates-thumbnail-images',
#    'CreationDate': datetime.datetime(2022, 6, 24, 18, 31, 12, tzinfo=tzutc())},
#   {'Name': 'lincoln-bucket-01',
#    'CreationDate': datetime.datetime(2023, 9, 28, 18, 18, 39, tzinfo=tzutc())},
#   {'Name': 'maaike-web-bucket',
#    'CreationDate': datetime.datetime(2024, 6, 26, 14, 28, 32, tzinfo=tzutc())},
#   {'Name': 'magesh-angular-gitlab-app',
#    'CreationDate': datetime.datetime(2023, 9, 22, 16, 34, 57, tzinfo=tzutc())},
#   {'Name': 'magesh-lambda-s3',
#    'CreationDate': datetime.datetime(2023, 9, 19, 16, 14, 34, tzinfo=tzutc())},
#   {'Name': 'malcolm-assesment-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 8, 16, 23, 13, tzinfo=tzutc())},
#   {'Name': 'malcolm-sam-app-ec2-535146832369-us-east-2',
#    'CreationDate': datetime.datetime(2023, 9, 21, 17, 36, 54, tzinfo=tzutc())},
#   {'Name': 'mchase-s3',
#    'CreationDate': datetime.datetime(2019, 9, 23, 15, 50, 47, tzinfo=tzutc())},
#   {'Name': 'mini-api-project-je',
#    'CreationDate': datetime.datetime(2024, 6, 27, 16, 24, 46, tzinfo=tzutc())},
#   {'Name': 'my-bucket-ds08057',
#    'CreationDate': datetime.datetime(2024, 6, 18, 16, 40, 4, tzinfo=tzutc())},
#   {'Name': 'my-bucket-et05298',
#    'CreationDate': datetime.datetime(2024, 6, 18, 16, 33, 55, tzinfo=tzutc())},
#   {'Name': 'my-bucket-kl08053',
#    'CreationDate': datetime.datetime(2024, 6, 18, 16, 23, 12, tzinfo=tzutc())},
#   {'Name': 'my-bucket2-et05298',
#    'CreationDate': datetime.datetime(2024, 6, 26, 16, 5, 38, tzinfo=tzutc())},
#   {'Name': 'my-build-bucket-sh03945',
#    'CreationDate': datetime.datetime(2024, 6, 24, 20, 34, 36, tzinfo=tzutc())},
#   {'Name': 'my-project-bucket-ov05296',
#    'CreationDate': datetime.datetime(2024, 6, 27, 16, 23, 42, tzinfo=tzutc())},
#   {'Name': 'my-s3-bucket-se05269',
#    'CreationDate': datetime.datetime(2024, 6, 26, 15, 11, 16, tzinfo=tzutc())},
#   {'Name': 'my-test-bucket-student20',
#    'CreationDate': datetime.datetime(2023, 10, 20, 19, 25, 33, tzinfo=tzutc())},
#   {'Name': 'my-tf-test-bucket-nabih',
#    'CreationDate': datetime.datetime(2021, 11, 8, 14, 19, 55, tzinfo=tzutc())},
#   {'Name': 'my-tf-test-bucket-student17',
#    'CreationDate': datetime.datetime(2023, 10, 19, 14, 43, 36, tzinfo=tzutc())},
#   {'Name': 'my-tf-test-bucket-student20',
#    'CreationDate': datetime.datetime(2023, 10, 20, 19, 25, 33, tzinfo=tzutc())},
#   {'Name': 'my-tf-test-bucket-student23',
#    'CreationDate': datetime.datetime(2023, 10, 19, 14, 34, 34, tzinfo=tzutc())},
#   {'Name': 'my-tf-test-bucket-teacher2',
#    'CreationDate': datetime.datetime(2023, 10, 19, 14, 47, 5, tzinfo=tzutc())},
#   {'Name': 'myawsbucket-ds08057',
#    'CreationDate': datetime.datetime(2024, 6, 26, 14, 28, 52, tzinfo=tzutc())},
#   {'Name': 'myawsbucket-kl08053',
#    'CreationDate': datetime.datetime(2024, 6, 26, 14, 49, 41, tzinfo=tzutc())},
#   {'Name': 'mybucket4efs.com',
#    'CreationDate': datetime.datetime(2021, 6, 24, 8, 55, 7, tzinfo=tzutc())},
#   {'Name': 'mybucket7707',
#    'CreationDate': datetime.datetime(2020, 1, 28, 15, 54, 21, tzinfo=tzutc())},
#   {'Name': 'mys3bucket-mk05255',
#    'CreationDate': datetime.datetime(2024, 6, 26, 16, 4, 3, tzinfo=tzutc())},
#   {'Name': 'nabila-bucket-raw',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 15, 33, tzinfo=tzutc())},
#   {'Name': 'nabila-bucket-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 28, 20, tzinfo=tzutc())},
#   {'Name': 'natali-assessment-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 8, 12, 42, 58, tzinfo=tzutc())},
#   {'Name': 'nsp-bucket-raw',
#    'CreationDate': datetime.datetime(2024, 6, 21, 11, 37, 2, tzinfo=tzutc())},
#   {'Name': 'nsp-bucket-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 21, 11, 45, 12, tzinfo=tzutc())},
#   {'Name': 'nullwpstage',
#    'CreationDate': datetime.datetime(2022, 7, 11, 15, 42, 55, tzinfo=tzutc())},
#   {'Name': 'orion-capstone',
#    'CreationDate': datetime.datetime(2021, 6, 21, 14, 51, 7, tzinfo=tzutc())},
#   {'Name': 'patrickmccardy-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 6, 13, 6, 8, tzinfo=tzutc())},
#   {'Name': 'reportbucketnff1',
#    'CreationDate': datetime.datetime(2021, 11, 10, 21, 5, 52, tzinfo=tzutc())},
#   {'Name': 'rjp-original-images',
#    'CreationDate': datetime.datetime(2022, 6, 27, 20, 5, 34, tzinfo=tzutc())},
#   {'Name': 'rjp-thumbnail-images',
#    'CreationDate': datetime.datetime(2022, 6, 27, 20, 5, 54, tzinfo=tzutc())},
#   {'Name': 'rx08052-web-bucket',
#    'CreationDate': datetime.datetime(2024, 6, 26, 15, 17, 46, tzinfo=tzutc())},
#   {'Name': 'sagemaker-course-di',
#    'CreationDate': datetime.datetime(2023, 11, 17, 11, 51, 31, tzinfo=tzutc())},
#   {'Name': 'sagemaker-studio-535146832369-db81fj1x82w',
#    'CreationDate': datetime.datetime(2023, 11, 17, 11, 54, 17, tzinfo=tzutc())},
#   {'Name': 'sagemaker-us-east-1-535146832369',
#    'CreationDate': datetime.datetime(2023, 11, 17, 12, 7, 26, tzinfo=tzutc())},
#   {'Name': 'sai-tf-test-bucket-sai',
#    'CreationDate': datetime.datetime(2023, 10, 19, 14, 48, 20, tzinfo=tzutc())},
#   {'Name': 'samee-hartford-bucket-raw',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 5, 18, tzinfo=tzutc())},
#   {'Name': 'samee-hartford-bucket-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 19, 44, tzinfo=tzutc())},
#   {'Name': 'se-bucket-100',
#    'CreationDate': datetime.datetime(2024, 6, 18, 16, 38, 4, tzinfo=tzutc())},
#   {'Name': 'seatownbucket88',
#    'CreationDate': datetime.datetime(2022, 6, 22, 23, 53, 37, tzinfo=tzutc())},
#   {'Name': 'sriya-pat-bucket-2-raw',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 28, 11, tzinfo=tzutc())},
#   {'Name': 'sriya-pat-bucket-2-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 20, 18, 34, 44, tzinfo=tzutc())},
#   {'Name': 'student-6-alternate',
#    'CreationDate': datetime.datetime(2023, 10, 20, 18, 20, 28, tzinfo=tzutc())},
#   {'Name': 'student-6-main',
#    'CreationDate': datetime.datetime(2023, 10, 20, 18, 20, 29, tzinfo=tzutc())},
#   {'Name': 'student17-terraform-provisioners-example',
#    'CreationDate': datetime.datetime(2023, 10, 19, 16, 3, 19, tzinfo=tzutc())},
#   {'Name': 'student22-ex06',
#    'CreationDate': datetime.datetime(2023, 10, 20, 15, 56, 51, tzinfo=tzutc())},
#   {'Name': 'su05297-web-bucket',
#    'CreationDate': datetime.datetime(2024, 6, 26, 15, 12, 33, tzinfo=tzutc())},
#   {'Name': 'super-unique-terraform-bucket',
#    'CreationDate': datetime.datetime(2024, 3, 18, 20, 52, 50, tzinfo=tzutc())},
#   {'Name': 'tarek-demo1-raw',
#    'CreationDate': datetime.datetime(2024, 6, 19, 14, 5, 36, tzinfo=tzutc())},
#   {'Name': 'tarek-demo1-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 19, 14, 25, 3, tzinfo=tzutc())},
#   {'Name': 'tarek-demo2',
#    'CreationDate': datetime.datetime(2024, 6, 20, 7, 44, 19, tzinfo=tzutc())},
#   {'Name': 'teacher2-terraform-provisioners-example',
#    'CreationDate': datetime.datetime(2023, 10, 19, 16, 13, 8, tzinfo=tzutc())},
#   {'Name': 'techcatalyst-raw',
#    'CreationDate': datetime.datetime(2024, 6, 27, 5, 26, 2, tzinfo=tzutc())},
#   {'Name': 'techcatalyst-transformed',
#    'CreationDate': datetime.datetime(2024, 6, 27, 8, 48, 43, tzinfo=tzutc())},
#   {'Name': 'techcatalyst-transformed-glue',
#    'CreationDate': datetime.datetime(2024, 6, 27, 11, 56, 31, tzinfo=tzutc())},
#   {'Name': 'terraform-di-student17',
#    'CreationDate': datetime.datetime(2023, 10, 20, 18, 57, 4, tzinfo=tzutc())},
#   {'Name': 'terraform-di-student17-alternate',
#    'CreationDate': datetime.datetime(2023, 10, 20, 18, 57, 4, tzinfo=tzutc())},
#   {'Name': 'terraform-lab5--42433',
#    'CreationDate': datetime.datetime(2023, 10, 20, 14, 37, 39, tzinfo=tzutc())},
#   {'Name': 'terraform-lab5--63647',
#    'CreationDate': datetime.datetime(2023, 10, 20, 14, 22, 7, tzinfo=tzutc())},
#   {'Name': 'terraform-lab5--64023',
#    'CreationDate': datetime.datetime(2023, 10, 19, 20, 57, 45, tzinfo=tzutc())},
#   {'Name': 'terraform-lab5--76528',
#    'CreationDate': datetime.datetime(2023, 10, 20, 14, 23, 3, tzinfo=tzutc())},
#   {'Name': 'terraform-lab5--92518',
#    'CreationDate': datetime.datetime(2024, 3, 19, 20, 52, 27, tzinfo=tzutc())},
#   {'Name': 'terraform-lab5--95453',
#    'CreationDate': datetime.datetime(2023, 10, 20, 14, 18, 38, tzinfo=tzutc())},
#   {'Name': 'test-connect-sh03945',
#    'CreationDate': datetime.datetime(2024, 6, 21, 13, 22, 32, tzinfo=tzutc())},
#   {'Name': 'thisisatestbucket123452439',
#    'CreationDate': datetime.datetime(2023, 9, 28, 14, 53, 56, tzinfo=tzutc())},
#   {'Name': 'tlopresti-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 5, 16, 21, 41, tzinfo=tzutc())},
#   {'Name': 'troy-aws-assessment-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 8, 17, 16, 14, tzinfo=tzutc())},
#   {'Name': 'vlh-student2',
#    'CreationDate': datetime.datetime(2023, 10, 20, 14, 39, 44, tzinfo=tzutc())},
#   {'Name': 'vlh-student2-us-east-2',
#    'CreationDate': datetime.datetime(2023, 10, 20, 18, 14, 50, tzinfo=tzutc())},
#   {'Name': 'will-assessment-bucket',
#    'CreationDate': datetime.datetime(2023, 9, 8, 16, 32, 8, tzinfo=tzutc())},
#   {'Name': 'will-lambda-s3',
#    'CreationDate': datetime.datetime(2023, 9, 19, 16, 14, 38, tzinfo=tzutc())},
#   {'Name': 'will-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 5, 18, 47, 31, tzinfo=tzutc())},
#   {'Name': 'wramey-lm-code-bucket',
#    'CreationDate': datetime.datetime(2020, 2, 5, 16, 30, 50, tzinfo=tzutc())}],
#  'Owner': {'DisplayName': 'aws+developintelligence',
#   'ID': '16069c045f149e9d758b52d41a2187e0bd07b3d749c95ba79eabeef755f2318a'}}

# %%
# use either a loop or list comprehension to extract the Bucket Names to a list. This is mainly for your reference in terms what are all the buckets available

buckets = [bucket['Name'] for bucket in response['Buckets']]

# %%
buckets
# Out:
# ['amsu-aws-s3-assessment',
#  'amsu-s3-cf-website',
#  'andrea-lm-code-bucket',
#  'aryan-aws-glue-activity-raw',
#  'aryan-aws-glue-activity-transformed',
#  'austin-lambda-s3',
#  'aws-athena-query-results-us-east-1-535146832369',
#  'aws-athena-query-results-us-east-1-535146832369-andy',
#  'aws-athena-query-results-us-east-1-535146832369nh',
#  'aws-athena-query-results-us-east-1-aryan',
#  'aws-athena-query-results-us-east-1-tarek',
#  'aws-athena-query-results-us-east-2-535146832369',
#  'aws-athena-query-results-us-east-2-535146832369-kb',
#  'aws-athena-query-results-us-east-2-nsp',
#  'aws-athena-query-results-us-east-2-sp',
#  'aws-cloudtrail-logs-535146832369-01f575cd',
#  'aws-cloudtrail-logs-535146832369-9d19bcae',
#  'aws-glue-assets-535146832369-us-east-1',
#  'aws-glue-assets-535146832369-us-east-2',
#  'aws-sam-cli-managed-default-samclisourcebucket-1oz2tqbsdli3',
#  'aws-sam-cli-managed-default-samclisourcebucket-mgdplk7mifi7',
#  'aws-sam-cli-managed-default-samclisourcebucket-t2x2wb9il3p1',
#  'aws-sam-cli-managed-default-samclisourcebucket-yh6y67cvomwp',
#  'axel-di-student14',
#  'axel-di-student2',
#  'axel-di-student25',
#  'axel-di-student8',
#  'axel-di-team2',
#  'barb-lm-code-bucket',
#  'brian-s3-demo',
#  'bryantbeach-original-images',
#  'bryantbeach-thumbnail-images',
#  'bucket-cl05355',
#  'bucket-terraform-lab4-41091',
#  'bucket-terraform-lab4-67147',
#  'bucket-terraform-lab4-82140',
#  'bucket-terraform-lab4-95407',
#  'bucket-terraform-lab4-98294',
#  'buggy-535146832369-us-east-1',
#  'bugs-app-stack-535146832369-us-east-2',
#  'calvin-lm-code-bucket',
#  'capstone-cloud-template-bucket',
#  'capstone-service-image',
#  'cf-templates-6dazn7owsddb-ap-south-1',
#  'cf-templates-6dazn7owsddb-us-east-1',
#  'cf-templates-6dazn7owsddb-us-east-2',
#  'cf-templates-6dazn7owsddb-us-west-2',
#  'codepipeline-us-east-2-68716816310',
#  'connor-awsassignment',
#  'connor-lambda-s3',
#  'connor-s3-cf-final-website',
#  'connor-s3-sqs',
#  'connorsbucketdemo',
#  'countingbucket-0',
#  'countingbucket-1',
#  'countingbucket-2',
#  'craig-lm-code-bucket',
#  'darrell-assessment-s3',
#  'david-s3-angular-assesment',
#  'davidprivatebucket',
#  'ddd434278923423',
#  'devint-2373',
#  'devint-4633',
#  'devint-6326',
#  'devint-8987',
#  'devint-auser1',
#  'devint-auser2',
#  'devint-dan2238',
#  'devint-krueger-alt',
#  'devint-std14-20220329062534398200000001',
#  'devint-std14-20220329062534458500000001',
#  'devint-std14-alt',
#  'devint-std17-20220329063555600900000001',
#  'devint-std17-20220329063555696700000001',
#  'devint-std17-alt',
#  'devint-std18-20220329063643571000000001',
#  'devint-std18-20220329063644010600000001',
#  'devint-std30-20220329110905171700000001',
#  'devint-std4-alt',
#  'devint-std7-alt',
#  'devint-std8-20220329064413559800000001',
#  'devint-std8-20220329064414038300000001',
#  'devint-student1-2515',
#  'devint-student1-4241',
#  'devint-student10-2515',
#  'devint-student10-4241',
#  'devint-student11-2515',
#  'devint-student11-4241',
#  'devint-student12-2515',
#  'devint-student12-4241',
#  'devint-student13-2515',
#  'devint-student13-4241',
#  'devint-student14',
#  'devint-student14-2515',
#  'devint-student14-4241',
#  'devint-student15-2515',
#  'devint-student15-4241',
#  'devint-student16-2515',
#  'devint-student16-4241',
#  'devint-student17-2515',
#  'devint-student17-4241',
#  'devint-student18-2515',
#  'devint-student18-4241',
#  'devint-student19-2515',
#  'devint-student19-4241',
#  'devint-student2-2515',
#  'devint-student2-4241',
#  'devint-student20',
#  'devint-student20-2515',
#  'devint-student20-4241',
#  'devint-student21-2515',
#  'devint-student21-4241',
#  'devint-student22',
#  'devint-student22-2515',
#  'devint-student22-4241',
#  'devint-student23-2515',
#  'devint-student23-4241',
#  'devint-student24-2515',
#  'devint-student24-4241',
#  'devint-student25-2515',
#  'devint-student3-2515',
#  'devint-student3-4241',
#  'devint-student4-2515',
#  'devint-student4-4241',
#  'devint-student5-2515',
#  'devint-student5-4241',
#  'devint-student6-2515',
#  'devint-student6-4241',
#  'devint-student7-2515',
#  'devint-student7-4241',
#  'devint-student8-2515',
#  'devint-student8-4241',
#  'devint-student9',
#  'devint-student9-2515',
#  'devint-student9-4241',
#  'devint-tabrej-alam-alt',
#  'digitalnomads',
#  'dooku2',
#  'dspera-lm-code-bucket',
#  'dws-di-corleone',
#  'dws-di-dooku-20220107144313147600000001',
#  'dws-di-jocker',
#  'dws-di-krueger',
#  'dws-di-nosferatu',
#  'dws-di-nosferatu-alt',
#  'dws-di-ramkumar',
#  'dws-di-spike',
#  'dws-di-student10',
#  'dws-di-tabrej-alam',
#  'dws-kattegat-ragnar',
#  'eamonn-test-bucket-865',
#  'eksworkshop-535146832369-codepipeline-artifacts',
#  'elasticbeanstalk-us-east-1-535146832369',
#  'elasticbeanstalk-us-east-2-535146832369',
#  'eoanifoeanfeionfiobvnuem',
#  'ferfybucket-assessment',
#  'first-bucket-es05260',
#  'first-web-app-bucket',
#  'first-web-app-cs08090',
#  'georgethomas-original-images',
#  'georgethomas-thumbnail-images',
#  'hark-assessment-bucket',
#  'hartford-bucket-andy-raw',
#  'hartford-bucket-andy-raw-transformed',
#  'hk-lambda-bucket',
#  'jalaunsbucket',
#  'jamesbrett-lm-code-bucket',
#  'jc-aws-athena-query-results-us-east-1',
#  'joe-lm-code-bucket',
#  'jonathanbardwellsbucket',
#  'jrrickerson-demo-cohort7',
#  'juliev1-bucket',
#  'kerim-test-bucket',
#  'lab-two',
#  'lcates-original-images',
#  'lcates-thumbnail-images',
#  'lincoln-bucket-01',
#  'maaike-web-bucket',
#  'magesh-angular-gitlab-app',
#  'magesh-lambda-s3',
#  'malcolm-assesment-bucket',
#  'malcolm-sam-app-ec2-535146832369-us-east-2',
#  'mchase-s3',
#  'mini-api-project-je',
#  'my-bucket-ds08057',
#  'my-bucket-et05298',
#  'my-bucket-kl08053',
#  'my-bucket2-et05298',
#  'my-build-bucket-sh03945',
#  'my-project-bucket-ov05296',
#  'my-s3-bucket-se05269',
#  'my-test-bucket-student20',
#  'my-tf-test-bucket-nabih',
#  'my-tf-test-bucket-student17',
#  'my-tf-test-bucket-student20',
#  'my-tf-test-bucket-student23',
#  'my-tf-test-bucket-teacher2',
#  'myawsbucket-ds08057',
#  'myawsbucket-kl08053',
#  'mybucket4efs.com',
#  'mybucket7707',
#  'mys3bucket-mk05255',
#  'nabila-bucket-raw',
#  'nabila-bucket-transformed',
#  'natali-assessment-bucket',
#  'nsp-bucket-raw',
#  'nsp-bucket-transformed',
#  'nullwpstage',
#  'orion-capstone',
#  'patrickmccardy-lm-code-bucket',
#  'reportbucketnff1',
#  'rjp-original-images',
#  'rjp-thumbnail-images',
#  'rx08052-web-bucket',
#  'sagemaker-course-di',
#  'sagemaker-studio-535146832369-db81fj1x82w',
#  'sagemaker-us-east-1-535146832369',
#  'sai-tf-test-bucket-sai',
#  'samee-hartford-bucket-raw',
#  'samee-hartford-bucket-transformed',
#  'se-bucket-100',
#  'seatownbucket88',
#  'sriya-pat-bucket-2-raw',
#  'sriya-pat-bucket-2-transformed',
#  'student-6-alternate',
#  'student-6-main',
#  'student17-terraform-provisioners-example',
#  'student22-ex06',
#  'su05297-web-bucket',
#  'super-unique-terraform-bucket',
#  'tarek-demo1-raw',
#  'tarek-demo1-transformed',
#  'tarek-demo2',
#  'teacher2-terraform-provisioners-example',
#  'techcatalyst-raw',
#  'techcatalyst-transformed',
#  'techcatalyst-transformed-glue',
#  'terraform-di-student17',
#  'terraform-di-student17-alternate',
#  'terraform-lab5--42433',
#  'terraform-lab5--63647',
#  'terraform-lab5--64023',
#  'terraform-lab5--76528',
#  'terraform-lab5--92518',
#  'terraform-lab5--95453',
#  'test-connect-sh03945',
#  'thisisatestbucket123452439',
#  'tlopresti-lm-code-bucket',
#  'troy-aws-assessment-bucket',
#  'vlh-student2',
#  'vlh-student2-us-east-2',
#  'will-assessment-bucket',
#  'will-lambda-s3',
#  'will-lm-code-bucket',
#  'wramey-lm-code-bucket']

# %%
# We care only about reading from ther 'techcatalyst-raw' bucket
bucket_name = 'techcatalyst-raw'

# %%
# Get all the objects inside that bucket. Once you get response, you can list all the keys. Remember, like a dictionary you have Key-Value pairs. We care about the Contents key.

# %%
# Print out the objects available. There are the Parquet files.

# %%
# Store them into a Python list to use later

# %%
import pandas as pd

# %%
# if you get this error: ImportError: Missing optional dependency 'fsspec'.  Use pip or conda to install fsspec. you just need to uncomment the below
# !conda install fsspec -y
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# uncomment if you did not install s3fs
# !conda install s3fs -c conda-forge -y
# Out:
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.

# %%
# run this example to make sure everything works

pd.read_parquet('s3://techcatalyst-raw/yellow_tripdata_2024-01.parquet',
               storage_options={
                   'key' : AWS_ACCESS_KEY,
                   'secret' : AWS_SECRET_KEY
               })
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1               1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2               1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3               1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4               1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
# ...           ...                  ...                   ...              ...
# 2964619         2  2024-01-31 23:45:59   2024-01-31 23:54:36              NaN
# 2964620         1  2024-01-31 23:13:07   2024-01-31 23:27:52              NaN
# 2964621         2  2024-01-31 23:19:00   2024-01-31 23:38:00              NaN
# 2964622         2  2024-01-31 23:07:23   2024-01-31 23:25:14              NaN
# 2964623         1  2024-01-31 23:58:25   2024-02-01 00:13:30              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 1.72         1.0                  N           186
# 1                 1.80         1.0                  N           140
# 2                 4.70         1.0                  N           236
# 3                 1.40         1.0                  N            79
# 4                 0.80         1.0                  N           211
# ...                ...         ...                ...           ...
# 2964619           3.18         NaN               None           107
# 2964620           4.00         NaN               None           114
# 2964621           3.33         NaN               None           211
# 2964622           3.06         NaN               None           107
# 2964623           8.10         NaN               None           138
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                  79             2        17.70   1.00      0.5        0.00
# 1                 236             1        10.00   3.50      0.5        3.75
# 2                  79             1        23.30   3.50      0.5        3.00
# 3                 211             1        10.00   3.50      0.5        2.00
# 4                 148             1         7.90   3.50      0.5        3.20
# ...               ...           ...          ...    ...      ...         ...
# 2964619           263             0        15.77   0.00      0.5        2.00
# 2964620           236             0        18.40   1.00      0.5        2.34
# 2964621            25             0        19.97   0.00      0.5        0.00
# 2964622            13             0        23.88   0.00      0.5        5.58
# 2964623            75             0        32.40   7.75      0.5        7.29
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                0.00                    1.0         22.70
# 1                0.00                    1.0         18.75
# 2                0.00                    1.0         31.30
# 3                0.00                    1.0         17.00
# 4                0.00                    1.0         16.10
# ...               ...                    ...           ...
# 2964619          0.00                    1.0         21.77
# 2964620          0.00                    1.0         25.74
# 2964621          0.00                    1.0         23.97
# 2964622          0.00                    1.0         33.46
# 2964623          6.94                    1.0         55.88
#
#          congestion_surcharge  Airport_fee
# 0                         2.5          0.0
# 1                         2.5          0.0
# 2                         2.5          0.0
# 3                         2.5          0.0
# 4                         2.5          0.0
# ...                       ...          ...
# 2964619                   NaN          NaN
# 2964620                   NaN          NaN
# 2964621                   NaN          NaN
# 2964622                   NaN          NaN
# 2964623                   NaN          NaN
#
# [2964624 rows x 19 columns]

# %% [markdown]
# ## Putting it all together

# %%
# Create a function that generates an s3:// URI 
# The function takes a bucket name, a file name and then constructs an s3:// uri that points to the object  

# https://repost.aws/questions/QUFXlwQxxJQQyg9PMn2b6nTg/what-is-s3-uri-in-simple-storage-service

# if you forgot how the s3:// uri looks like then please login to AWS and navigate to S3 services and see how an object inside a bucket is being referenced by the s3:// uri

def generate_url(bucket, file):
    uri = f's3://{bucket}/Sriya/{file}'
    return uri

# %%
# Create a cleanup function that takes three parameters: the DataFrame, the name of the file, the destination bucket

# the function will transform the data then write out a Parquet file to the destination address 
from datetime import datetime

def cleanup(df, name, dest):
    print(f'processing {name}')
    print("..........")

    df['Trip_Duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() // 60
    df['Total_Trip_Charge'] = df['fare_amount'] + df['extra'] + df['mta_tax'] + df['tolls_amount'] + df['improvement_surcharge'] + df['congestion_surcharge'] + df['Airport_fee'] + df['tip_amount']

    df['Trip_Date'] = pd.to_datetime(df['tpep_pickup_datetime'].dt.date)
    df['Trip_Month'] = df['Trip_Date'].dt.month_name()
    df['Trip_Day'] = df['Trip_Date'].dt.day_name()
    df['Trip_Year'] = df['Trip_Date'].dt.year

    cols = ['VendorID', 'Trip_Date', 'Trip_Year', 'Trip_Month', 'Trip_Day',
       'passenger_count', 'trip_distance', 'store_and_fwd_flag',
       'payment_type', 'Trip_Duration',
       'Total_Trip_Charge' ]
    df = df[cols]

    df.rename(columns={
    'VendorID': 'Vendor_ID',
    'passenger_count': 'No_of_Passengers',
    'store_and_fwd_flag': 'SF_Flag',
    'payment_type': 'Payment_Type'
}, inplace=True)

    # df.to_parquet('Yellow Taxi Transformed.parquet', partition_cols=['Trip_Year', 'Trip_Month'])
    uri = generate_url(dest, name)
    print(f'{name} to {dest} bucket')
    print("..........")
    df.to_parquet(uri, partition_cols=['Trip_Year', 'Trip_Month'], storage_options= {
                         'key': AWS_ACCESS_KEY,
                         'secret': AWS_SECRET_KEY
                     })
    
    

    
    
    

   # Write your code here


    return None # replace None with the proper value

# %%
# processing yellow_tripdata_2024-01.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-01.parquet to techcatalyst-transformed bucket
# ...........
# processing yellow_tripdata_2024-02.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-02.parquet to techcatalyst-transformed bucket
# ...........
# processing yellow_tripdata_2024-03.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-03.parquet to techcatalyst-transformed bucket
# ...........
# processing yellow_tripdata_2024-04.parquet
# ...........
# writing s3://techcatalyst-raw/yellow_tripdata_2024-04.parquet to techcatalyst-transformed bucket



bucket_dest = 'techcatalyst-transformed'
bucket_source = 'techcatalyst-raw'

objects = s3client.list_objects_v2(Bucket=bucket_source)
myfiles = [obj['Key'] for obj in objects['Contents']]
# print(myfiles)

for i in range(len(myfiles)):
    imported_df = pd.read_parquet(f's3://{bucket_source}/{myfiles[i]}', 
                     storage_options= {
                         'key': AWS_ACCESS_KEY,
                         'secret': AWS_SECRET_KEY
                     })
    cleanup(imported_df, myfiles[i], bucket_dest)
    
    
    
    
# # Write your code that leverages the functions you just created 
# # Your functions should perform the ETL but should also print out some status as shown
# Out:
# processing yellow_tripdata_2024-01.parquet
# ..........
# /tmp/ipykernel_143454/2132228140.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
# yellow_tripdata_2024-01.parquet to techcatalyst-transformed bucket
# ..........
# processing yellow_tripdata_2024-02.parquet
# ..........
# /tmp/ipykernel_143454/2132228140.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
# yellow_tripdata_2024-02.parquet to techcatalyst-transformed bucket
# ..........
# processing yellow_tripdata_2024-03.parquet
# ..........
# /tmp/ipykernel_143454/2132228140.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
# yellow_tripdata_2024-03.parquet to techcatalyst-transformed bucket
# ..........
# processing yellow_tripdata_2024-04.parquet
# ..........
# /tmp/ipykernel_143454/2132228140.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={
# yellow_tripdata_2024-04.parquet to techcatalyst-transformed bucket
# ..........

# %%
# Example of the statistics collected from each file before writing (loading). Can you think of other information you can capture? Maybe stats before and after?
